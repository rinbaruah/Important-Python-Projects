# %%
import numpy as np
import pandas as pd
import plotly as py
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs 
from plotly.offline import init_notebook_mode
from plotly.offline import plot,iplot
init_notebook_mode(connected=True)
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
raw_data=pd.read_csv('AgeGroupDetails.csv')
df_test=raw_data.copy()

df_test.drop('Sno',axis=1,inplace=True)

# %%
df_test
# Out:
#   AgeGroup  TotalCases Percentage
# 0      0-9          22      3.18%
# 1    10-19          27      3.90%
# 2    20-29         172     24.86%
# 3    30-39         146     21.10%
# 4    40-49         112     16.18%
# 5    50-59          77     11.13%
# 6    60-69          89     12.86%
# 7    70-79          28      4.05%
# 8     >=80          10      1.45%
# 9  Missing           9      1.30%

# %%
sns.barplot('AgeGroup','TotalCases',data=df_test)
plt.title('Cases by age group')
# Out:
# Text(0.5, 1.0, 'Cases by age group')

# %%
values=[]
for i in range(10):
    values.append(df_test.TotalCases[i])
    i+=1
plt.pie(values,labels=df_test.AgeGroup,autopct='%1.1f%%')
plt.title('Pie chart distribution of all the effected age groups by COVID-19')
# Out:
# Text(0.5, 1.0, 'Pie chart distribution of all the effected age groups by COVID-19')

# %%
sns.kdeplot(df_test['TotalCases'])
