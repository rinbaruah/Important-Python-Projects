# %%
# For time stamps
from datetime import datetime



import pandas as pd
import numpy as np

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
from pandas_datareader import DataReader
from datetime import datetime

# %%
tech_list=['AAPL','GOOG','MSFT','AMZN']

# %%
end=datetime.now()

# %%
start=datetime(end.year-1,end.month,end.day)

# %%
end
# Out:
# datetime.datetime(2020, 4, 4, 21, 24, 58, 587525)

# %%
start
# Out:
# datetime.datetime(2019, 4, 4, 0, 0)

# %%
for stock in tech_list:
    globals()[stock]=DataReader(stock,'yahoo',start,end)

# %%
GOOG['Adj Close'].plot(legend=True,figsize=(10,4))

# %%
AMZN['Adj Close'].plot(legend=True,figsize=(10,4))

# %%
AAPL['Adj Close'].plot(legend=True,figsize=(10,4))

# %%
AAPL['Volume'].plot(legend=True,figsize=(10,4))

# %%
AAPL
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-04-03  196.500000  193.149994  193.250000  195.350006  23271800.0
# 2019-04-04  196.369995  193.139999  194.789993  195.690002  19114300.0
# 2019-04-05  197.100006  195.929993  196.449997  197.000000  18526600.0
# 2019-04-08  200.229996  196.339996  196.419998  200.100006  25881700.0
# 2019-04-09  202.850006  199.229996  200.320007  199.500000  35768200.0
# ...                ...         ...         ...         ...         ...
# 2020-03-30  255.520004  249.399994  250.740005  254.809998  41994100.0
# 2020-03-31  262.489990  252.000000  255.600006  254.289993  49250500.0
# 2020-04-01  248.720001  239.130005  246.500000  240.910004  44054600.0
# 2020-04-02  245.149994  236.899994  240.339996  244.929993  41483500.0
# 2020-04-03  245.699997  238.970001  242.800003  241.410004  32418200.0
#
#              Adj Close
# Date
# 2019-04-03  192.826111
# 2019-04-04  193.161682
# 2019-04-05  194.454758
# ...

# %%
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   241.419094  236.201851  238.480944  239.020275  3.243345e+07
# std     43.548367   42.274969   42.783322   43.111613  1.727686e+07
# min    177.919998  170.270004  175.440002  173.300003  1.136200e+07
# 25%    204.955002  201.650005  203.162502  203.155003  2.129230e+07
# 50%    226.955002  221.824997  224.935005  224.169998  2.702655e+07
# 75%    270.949997  265.370010  267.427505  268.320007  3.597765e+07
# max    327.850006  323.350006  324.739990  327.200012  1.067212e+08
#
#         Adj Close
# count  254.000000
# mean   237.845370
# std     43.681149
# min    171.719727
# 25%    201.394157
# 50%    222.984741
# 75%    267.684708
# max    327.200012

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2019-04-03 to 2020-04-03
# Data columns (total 6 columns):
# High         254 non-null float64
# Low          254 non-null float64
# Open         254 non-null float64
# Close        254 non-null float64
# Volume       254 non-null float64
# Adj Close    254 non-null float64
# dtypes: float64(6)
# memory usage: 13.9 KB

# %%
ma_day=[10,20,50]

for ma in ma_day:
    column_name=("MA for {} days".format(ma))
    AAPL[column_name]=AAPL.Volume.rolling(ma).mean()

# %%
AAPL[['Volume','MA for 10 days','MA for 20 days',
      'MA for 50 days']].plot(subplots=False,figsize=(10,4))

# %%
AAPL
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-04-03  196.500000  193.149994  193.250000  195.350006  23271800.0
# 2019-04-04  196.369995  193.139999  194.789993  195.690002  19114300.0
# 2019-04-05  197.100006  195.929993  196.449997  197.000000  18526600.0
# 2019-04-08  200.229996  196.339996  196.419998  200.100006  25881700.0
# 2019-04-09  202.850006  199.229996  200.320007  199.500000  35768200.0
# ...                ...         ...         ...         ...         ...
# 2020-03-30  255.520004  249.399994  250.740005  254.809998  41994100.0
# 2020-03-31  262.489990  252.000000  255.600006  254.289993  49250500.0
# 2020-04-01  248.720001  239.130005  246.500000  240.910004  44054600.0
# 2020-04-02  245.149994  236.899994  240.339996  244.929993  41483500.0
# 2020-04-03  245.699997  238.970001  242.800003  241.410004  32418200.0
#
#              Adj Close  MA for 10 days  MA for 20 days  MA for 50 days
# Date
# ...

# %%
AAPL['Adj_Close']=AAPL['Adj Close']

# %%
AAPL=AAPL.drop('Adj Close',axis=1)

# %%
AAPL
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-04-03  196.500000  193.149994  193.250000  195.350006  23271800.0
# 2019-04-04  196.369995  193.139999  194.789993  195.690002  19114300.0
# 2019-04-05  197.100006  195.929993  196.449997  197.000000  18526600.0
# 2019-04-08  200.229996  196.339996  196.419998  200.100006  25881700.0
# 2019-04-09  202.850006  199.229996  200.320007  199.500000  35768200.0
# ...                ...         ...         ...         ...         ...
# 2020-03-30  255.520004  249.399994  250.740005  254.809998  41994100.0
# 2020-03-31  262.489990  252.000000  255.600006  254.289993  49250500.0
# 2020-04-01  248.720001  239.130005  246.500000  240.910004  44054600.0
# 2020-04-02  245.149994  236.899994  240.339996  244.929993  41483500.0
# 2020-04-03  245.699997  238.970001  242.800003  241.410004  32418200.0
#
#             MA for 10 days  MA for 20 days  MA for 50 days   Adj_Close
# Date
# ...

# %%
ma_day=[10,20,50]

for ma in ma_day:
    column_name=("MA for {} days".format(ma))
    AAPL[column_name]=AAPL.Adj_Close.rolling(ma).mean()

# %%
AAPL[['Adj_Close','MA for 10 days','MA for 20 days',
      'MA for 50 days']].plot(subplots=False,figsize=(10,4))

# %% [markdown]
# Moving averages help us understand the time series data trend better. It helps smooth out price action by filtering out  the noise fro random short term price fluctuations.

# %%
AAPL['Daily_Return']=AAPL['Adj_Close'].pct_change()
AAPL['Daily_Return'].plot(figsize=(10,4),legend=True,
                          linestyle='--',marker='o')

# %%
sns.distplot(AAPL['Daily_Return'].dropna(),bins=100,color='green')

# %%
AAPL['Daily_Return'].hist(bins=100,color='purple')

# %%
closing_df=DataReader(tech_list,'yahoo',start,end)['Adj Close']

# %% [markdown]
# In the above code, we are forming a dataframe where we take just the data of Adj Close

# %%
closing_df
# Out:
# Symbols           AAPL         GOOG        MSFT         AMZN
# Date
# 2019-04-03  192.826111  1205.920044  118.403458  1820.699951
# 2019-04-04  193.161682  1215.000000  117.801422  1818.859985
# 2019-04-05  194.454758  1207.150024  118.324493  1837.280029
# 2019-04-08  197.514709  1203.839966  118.363968  1849.859985
# 2019-04-09  196.922470  1197.250000  117.722450  1835.839966
# ...                ...          ...         ...          ...
# 2020-03-30  254.809998  1146.819946  160.229996  1963.949951
# 2020-03-31  254.289993  1162.810059  157.710007  1949.719971
# 2020-04-01  240.910004  1105.619995  152.110001  1907.699951
# 2020-04-02  244.929993  1120.839966  155.259995  1918.829956
# 2020-04-03  241.410004  1097.880005  153.830002  1906.589966
#
# [254 rows x 4 columns]

# %%
tech_rets=closing_df.pct_change()

# %%
tech_rets
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2019-04-03       NaN       NaN       NaN       NaN
# 2019-04-04  0.001740  0.007529 -0.005085 -0.001011
# 2019-04-05  0.006694 -0.006461  0.004440  0.010127
# 2019-04-08  0.015736 -0.002742  0.000334  0.006847
# 2019-04-09 -0.002998 -0.005474 -0.005420 -0.007579
# ...              ...       ...       ...       ...
# 2020-03-30  0.028538  0.032511  0.070341  0.033603
# 2020-03-31 -0.002041  0.013943 -0.015727 -0.007246
# 2020-04-01 -0.052617 -0.049183 -0.035508 -0.021552
# 2020-04-02  0.016687  0.013766  0.020709  0.005834
# 2020-04-03 -0.014371 -0.020485 -0.009210 -0.006379
#
# [254 rows x 4 columns]

# %%
tech_rets.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2019-04-03       NaN       NaN       NaN       NaN
# 2019-04-04  0.001740  0.007529 -0.005085 -0.001011
# 2019-04-05  0.006694 -0.006461  0.004440  0.010127
# 2019-04-08  0.015736 -0.002742  0.000334  0.006847
# 2019-04-09 -0.002998 -0.005474 -0.005420 -0.007579

# %%
sns.jointplot('GOOG','GOOG',tech_rets,kind='scatter',color='seagreen')

# %%
sns.jointplot('GOOG','AAPL',tech_rets,kind='scatter',color='seagreen')

# %%
sns.jointplot('GOOG','MSFT',tech_rets,kind='scatter',color='seagreen')

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig=sns.PairGrid(tech_rets.dropna())
returns_fig.map_upper(plt.scatter,color='seagreen')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30,color='indianred')

# %%
returns_fig=sns.PairGrid(closing_df.dropna())
returns_fig.map_upper(plt.scatter,color='seagreen')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30,color='indianred')

# %%
sns.heatmap(tech_rets.dropna(),annot=True)

# %%
rets=tech_rets.dropna()

# %%
area=np.pi*20
plt.scatter(rets.mean(),rets.std(),s=area)
plt.xlabel('Expected Return')
plt.ylabel('Risk')

plt.xlim(-0.003,0.004)
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3',color='indianred'))

# %% [markdown]
# AAPL and MSFT have a really similar behaviour

# %% [markdown]
# AMZN has low risk and decent returns

# %%
sns.distplot(AAPL['Daily_Return'].dropna(),bins=100,color='purple')

# %%
rets['AAPL'].quantile(0.05)
# Out:
# -0.034215511527353734

# %% [markdown]
# The 0.05 empirical quantile of daily returns is at -0.019. That means that with 95% confidence, our worst daily loss will not exceed 3.42%. If we have a 1 million dollar investment, our one-day 5% VaR is 0.0342 * 1,000,000 = $34,200.

# %%
rets['MSFT'].quantile(0.05)
# Out:
# -0.03171252089068059

# %%
rets['GOOG'].quantile(0.05)
# Out:
# -0.03457167691969172

# %%
rets['AMZN'].quantile(0.05)
# Out:
# -0.027107389985096694

# %%
day=365
dt=1/365
mu=rets.mean()['AAPL']
sigma=rets.std()['AAPL']

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
    price=np.zeros(days)
    price[0]=start_price
    shock=np.zeros(days)
    drift=np.zeros(days)
    
    for x in range(1,days):
        shock[x]=np.random.normal(loc=mu*dt,scale=sigma*np.sqrt(dt))
        
        drift[x]=mu*dt
        
        price[x]=price[x-1]+(price[x-1]*(drift[x]+shock[x]))
    return price

# %%
AAPL.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-04-03  196.500000  193.149994  193.250000  195.350006  23271800.0
# 2019-04-04  196.369995  193.139999  194.789993  195.690002  19114300.0
# 2019-04-05  197.100006  195.929993  196.449997  197.000000  18526600.0
# 2019-04-08  200.229996  196.339996  196.419998  200.100006  25881700.0
# 2019-04-09  202.850006  199.229996  200.320007  199.500000  35768200.0
#
#             MA for 10 days  MA for 20 days  MA for 50 days   Adj_Close  \
# Date
# 2019-04-03             NaN             NaN             NaN  192.826111
# 2019-04-04             NaN             NaN             NaN  193.161682
# 2019-04-05             NaN             NaN             NaN  194.454758
# 2019-04-08             NaN             NaN             NaN  197.514709
# 2019-04-09             NaN             NaN             NaN  196.922470
#
#             Daily_Return
# Date
# 2019-04-03           NaN
# 2019-04-04      0.001740
# ...

# %%
start_price=202.85
for run in range(100):
    plt.plot(stock_monte_carlo(start_price,day,mu,sigma))
    
plt.xlabel('days',size=18)
plt.ylabel('price',size=18)
plt.title('Monte Carlo Analysis',size=25)
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis')

# %%
runs=10000
simulations=np.zeros(runs)
for run in range(runs):
    simulations[run]=stock_monte_carlo(start_price,day,mu,sigma)[day-1]

# %% [markdown]
# The [day-1] is used to gather all the data of the end price on 365th day and store it in the simulations array

# %%
q=np.percentile(simulations,1)
plt.hist(simulations,bins=200,color='seagreen')
plt.figtext(0.6,0.8,s="Starting price: {}".format(start_price))
plt.figtext(0.6,0.7,"Mean final price: {}".format(np.round(simulations.mean(),3)))
plt.figtext(0.6,0.6,"Variance (0.99): {} $".format(np.round(start_price-q,3)))
plt.axvline(x=q,linewidth=4,color='indianred')
plt.title("Final price distribution of Apple")
# Out:
# Text(0.5, 1.0, 'Final price distribution of Apple')

# %%
np.percentile(simulations,1)
# Out:
# 192.06747387243016

# %% [markdown]
# Above code shows 1 percent emperical quantile or 99 percentile

# %% [markdown]
# This means that 99 percent of the times, it must fit the value
